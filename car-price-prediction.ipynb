# %%
import pandas as pd
import numpy as np

# %%
cars = pd.read_csv("/kaggle/input/car-price-predictionused-cars/car data.csv")

# %%
cars.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
cars = cars[['Year', 'Selling_Price', 'Present_Price', 'Driven_kms', 'Fuel_Type', 'Selling_type','Transmission']]

# %%
cars
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0    2014           3.35           5.59       27000    Petrol       Dealer
# 1    2013           4.75           9.54       43000    Diesel       Dealer
# 2    2017           7.25           9.85        6900    Petrol       Dealer
# 3    2011           2.85           4.15        5200    Petrol       Dealer
# 4    2014           4.60           6.87       42450    Diesel       Dealer
# ..    ...            ...            ...         ...       ...          ...
# 296  2016           9.50          11.60       33988    Diesel       Dealer
# 297  2015           4.00           5.90       60000    Petrol       Dealer
# 298  2009           3.35          11.00       87934    Petrol       Dealer
# 299  2017          11.50          12.50        9000    Diesel       Dealer
# 300  2016           5.30           5.90        5464    Petrol       Dealer
#
#     Transmission
# 0         Manual
# 1         Manual
# ...

# %%
cars['Year'].value_counts()
# Out:
# Year
# 2015    61
# 2016    50
# 2014    38
# 2017    35
# 2013    33
# 2012    23
# 2011    19
# 2010    15
# 2008     7
# 2009     6
# 2006     4
# 2005     4
# 2003     2
# 2007     2
# 2018     1
# 2004     1
# Name: count, dtype: int64

# %%
cars['Selling_Price'].unique()
# Out:
# array([ 3.35,  4.75,  7.25,  2.85,  4.6 ,  9.25,  6.75,  6.5 ,  8.75,
#         7.45,  6.85,  7.5 ,  6.1 ,  2.25,  7.75,  3.25,  2.65,  4.9 ,
#         4.4 ,  2.5 ,  2.9 ,  3.  ,  4.15,  6.  ,  1.95,  3.1 ,  2.35,
#         4.95,  5.5 ,  2.95,  4.65,  0.35,  5.85,  2.55,  1.25,  1.05,
#         5.8 , 14.9 , 23.  , 18.  , 16.  ,  2.75,  3.6 ,  4.5 ,  4.1 ,
#        19.99,  6.95, 18.75, 23.5 , 33.  , 19.75,  4.35, 14.25,  3.95,
#         1.5 ,  5.25, 14.5 , 14.73, 12.5 ,  3.49, 35.  ,  5.9 ,  3.45,
#         3.8 , 11.25,  3.51,  4.  , 20.75, 17.  ,  7.05,  9.65,  1.75,
#         1.7 ,  1.65,  1.45,  1.35,  1.2 ,  1.15,  1.11,  1.1 ,  1.  ,
#         0.95,  0.9 ,  0.75,  0.8 ,  0.78,  0.72,  0.65,  0.6 ,  0.55,
#         0.52,  0.51,  0.5 ,  0.48,  0.45,  0.42,  0.4 ,  0.38,  0.31,
#         0.3 ,  0.27,  0.25,  0.2 ,  0.18,  0.17,  0.16,  0.15,  0.12,
#         0.1 ,  5.75,  5.15,  7.9 ,  4.85, 11.75,  3.15,  6.45,  3.5 ,
# ...

# %%
cars['Present_Price'].unique()
# Out:
# array([ 5.59 ,  9.54 ,  9.85 ,  4.15 ,  6.87 ,  9.83 ,  8.12 ,  8.61 ,
#         8.89 ,  8.92 ,  3.6  , 10.38 ,  9.94 ,  7.71 ,  7.21 , 10.79 ,
#         5.09 ,  7.98 ,  3.95 ,  5.71 ,  8.01 ,  3.46 ,  4.41 ,  4.99 ,
#         5.87 ,  6.49 ,  5.98 ,  4.89 ,  7.49 ,  9.95 ,  8.06 ,  7.74 ,
#         7.2  ,  2.28 ,  3.76 ,  7.87 ,  3.98 ,  7.15 ,  2.69 , 12.04 ,
#         9.29 , 30.61 , 19.77 , 10.21 , 15.04 ,  7.27 , 18.54 ,  6.8  ,
#        35.96 , 18.61 ,  7.7  , 36.23 ,  6.95 , 23.15 , 20.45 , 13.74 ,
#        20.91 ,  6.76 , 12.48 ,  8.93 , 14.68 , 12.35 , 22.83 , 14.89 ,
#         7.85 , 25.39 , 13.46 , 23.73 , 92.6  ,  6.05 , 16.09 , 13.7  ,
#        22.78 , 18.64 ,  1.9  ,  1.82 ,  1.78 ,  1.6  ,  1.47 ,  2.37 ,
#         3.45 ,  1.5  ,  2.4  ,  1.4  ,  1.26 ,  1.17 ,  1.75 ,  0.95 ,
#         0.8  ,  0.87 ,  0.84 ,  0.82 ,  0.81 ,  0.74 ,  1.2  ,  0.787,
#         0.99 ,  0.94 ,  0.826,  0.55 ,  0.88 ,  0.51 ,  0.52 ,  0.54 ,
# ...

# %%
cars['Selling_type'].value_counts()
# Out:
# Selling_type
# Dealer        195
# Individual    106
# Name: count, dtype: int64

# %%
numerical_features_data = cars[['Year', 'Selling_Price', 'Present_Price', 'Driven_kms']]

# %%
print(numerical_features_data.corr())
# Out:
#                    Year  Selling_Price  Present_Price  Driven_kms
# Year           1.000000       0.236141      -0.047192   -0.524342
# Selling_Price  0.236141       1.000000       0.878914    0.029187
# Present_Price -0.047192       0.878914       1.000000    0.203618
# Driven_kms    -0.524342       0.029187       0.203618    1.000000

# %%
cars.isnull().count()
# Out:
# Year             301
# Selling_Price    301
# Present_Price    301
# Driven_kms       301
# Fuel_Type        301
# Selling_type     301
# Transmission     301
# dtype: int64

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           301 non-null    int64
#  1   Selling_Price  301 non-null    float64
#  2   Present_Price  301 non-null    float64
#  3   Driven_kms     301 non-null    int64
#  4   Fuel_Type      301 non-null    object
#  5   Selling_type   301 non-null    object
#  6   Transmission   301 non-null    object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 16.6+ KB

# %%
cars
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0    2014           3.35           5.59       27000    Petrol       Dealer
# 1    2013           4.75           9.54       43000    Diesel       Dealer
# 2    2017           7.25           9.85        6900    Petrol       Dealer
# 3    2011           2.85           4.15        5200    Petrol       Dealer
# 4    2014           4.60           6.87       42450    Diesel       Dealer
# ..    ...            ...            ...         ...       ...          ...
# 296  2016           9.50          11.60       33988    Diesel       Dealer
# 297  2015           4.00           5.90       60000    Petrol       Dealer
# 298  2009           3.35          11.00       87934    Petrol       Dealer
# 299  2017          11.50          12.50        9000    Diesel       Dealer
# 300  2016           5.30           5.90        5464    Petrol       Dealer
#
#     Transmission
# 0         Manual
# 1         Manual
# ...

# %%
cars.replace({'Fuel_Type':{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)
cars.replace({'Selling_type':{'Dealer':0,'Individual':1}},inplace=True)
cars.replace({'Transmission':{'Manual':0,'Automatic':1}},inplace=True)
# Out:
# /tmp/ipykernel_1067/626890882.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cars.replace({'Fuel_Type':{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)
# /tmp/ipykernel_1067/626890882.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cars.replace({'Selling_type':{'Dealer':0,'Individual':1}},inplace=True)
# ...

# %%
cars['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# 0    239
# 1     60
# 2      2
# Name: count, dtype: int64

# %%
X = cars.drop('Selling_Price', axis=1)
y = cars['Selling_Price']

# %%
X.shape, y.shape
# Out:
# ((301, 6), (301,))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=69)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
lin_reg = LinearRegression()

# %%
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = lin_reg.predict(X_train)
y_test_pred = lin_reg.predict(X_test)

# %%
print("Coefficient of Determination R2 on train set:", lin_reg.score(X_train, y_train))
print("Coefficient of Determination R2 on test set:", lin_reg.score(X_test, y_test))
# Out:
# Coefficient of Determination R2 on train set: 0.8735903127907101
# Coefficient of Determination R2 on test set: 0.88512990895136

# %%
mse_train = mean_squared_error(y_train_pred, y_train)
mse_test = mean_squared_error(y_test_pred, y_test)

print("Mean Squared Error on train set:", mse_train)
print("Mean Squared Error on test set:", mse_test)
# Out:
# Mean Squared Error on train set: 3.618003857192009
# Mean Squared Error on test set: 1.9805671895386392

# %%
mae_train = mean_absolute_error(y_train_pred, y_train)
mae_test = mean_absolute_error(y_test_pred, y_test)

print("Mean Absolute Error on train set:", mae_train)
print("Mean Absolute Error on test set:", mae_test)
# Out:
# Mean Absolute Error on train set: 1.2799889619677864
# Mean Absolute Error on test set: 1.021641683293004

# %%
cars
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  Selling_type  \
# 0    2014           3.35           5.59       27000          0             0
# 1    2013           4.75           9.54       43000          1             0
# 2    2017           7.25           9.85        6900          0             0
# 3    2011           2.85           4.15        5200          0             0
# 4    2014           4.60           6.87       42450          1             0
# ..    ...            ...            ...         ...        ...           ...
# 296  2016           9.50          11.60       33988          1             0
# 297  2015           4.00           5.90       60000          0             0
# 298  2009           3.35          11.00       87934          0             0
# 299  2017          11.50          12.50        9000          1             0
# 300  2016           5.30           5.90        5464          0             0
#
#      Transmission
# 0               0
# ...

# %%
new_car = [[2016, 5.90, 5464, 1, 0, 0]] 
predicted_price = lin_reg.predict(new_car)
print('Predicted Selling Price:', predicted_price[0], "Lakhs")
# Out:
# Predicted Selling Price: 6.852161431008199 Lakhs
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
def train_eval_models(X_train, X_test, y_train, y_test, estimator):
    estimator.fit(X_train, y_train)
    
    y_train_pred = estimator.predict(X_train)
    y_test_pred = estimator.predict(X_test)
    
    print("Coefficient of Determination R2 on train set:", estimator.score(X_train, y_train))
    print("Coefficient of Determination R2 on test set:", estimator.score(X_test, y_test))
    
    print()
    print()
    
    mse_train = mean_squared_error(y_train_pred, y_train)
    mse_test = mean_squared_error(y_test_pred, y_test)

    print("Mean Squared Error on train set:", mse_train)
    print("Mean Squared Error on test set:", mse_test)
    
    print()
    print()
    mae_train = mean_absolute_error(y_train_pred, y_train)
    mae_test = mean_absolute_error(y_test_pred, y_test)

    print("Mean Absolute Error on train set:", mae_train)
    print("Mean Absolute Error on test set:", mae_test)

# %%
from sklearn.linear_model import SGDRegressor, Ridge, Lasso

# %%
model1 = SGDRegressor()
model2 = Ridge()
model3 = Lasso()

# %%
print("Performance of Stochastic Gradient Descent Regressor: ")
train_eval_models(X_train, X_test, y_train, y_test, model1)
# Out:
# Performance of Stochastic Gradient Descent Regressor:
# Coefficient of Determination R2 on train set: -2.0478217325943917e+34
# Coefficient of Determination R2 on test set: -1.697840223209455e+34
#
#
# Mean Squared Error on train set: 5.861122743782597e+35
# Mean Squared Error on test set: 2.927382235419078e+35
#
#
# Mean Absolute Error on train set: 5.117538091964811e+17
# Mean Absolute Error on test set: 4.443446776701913e+17

# %%
print("Performance of Ridge Regressor: ")
train_eval_models(X_train, X_test, y_train, y_test, model2)
# Out:
# Performance of Ridge Regressor:
# Coefficient of Determination R2 on train set: 0.8735462746910716
# Coefficient of Determination R2 on test set: 0.8876573994521021
#
#
# Mean Squared Error on train set: 3.619264282859321
# Mean Squared Error on test set: 1.936988702641466
#
#
# Mean Absolute Error on train set: 1.2765250911396824
# Mean Absolute Error on test set: 1.0126062665434328

# %%
print("Performance of Lasso Regressor: ")
train_eval_models(X_train, X_test, y_train, y_test, model3)
# Out:
# Performance of Lasso Regressor:
# Coefficient of Determination R2 on train set: 0.8352275505452198
# Coefficient of Determination R2 on test set: 0.8796073302252185
#
#
# Mean Squared Error on train set: 4.71599424733454
# Mean Squared Error on test set: 2.0757863900005638
#
#
# Mean Absolute Error on train set: 1.3501001998701583
# Mean Absolute Error on test set: 1.0552039464063026

# %%
new_car = [[2016, 5.90, 5464, 1, 0, 0]] 
predicted_price = model1.predict(new_car)
print('Predicted Selling Price by SGD:', predicted_price[0], "Lakhs")
# Out:
# Predicted Selling Price by SGD: 7.5479570489421e+16 Lakhs
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SGDRegressor was fitted with feature names
#   warnings.warn(

# %%
new_car = [[2016, 5.90, 5464, 1, 0, 0]] 
predicted_price = model2.predict(new_car)
print('Predicted Selling Price by Ridge:', predicted_price[0], "Lakhs")
# Out:
# Predicted Selling Price by Ridge: 6.791974669188448 Lakhs
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but Ridge was fitted with feature names
#   warnings.warn(

# %%
new_car = [[2016, 5.90, 5464, 1, 0, 0]] 
predicted_price = model2.predict(new_car)
print('Predicted Selling Price by Lasso:', predicted_price[0], "Lakhs")
# Out:
# Predicted Selling Price by Lasso: 6.791974669188448 Lakhs
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but Ridge was fitted with feature names
#   warnings.warn(
